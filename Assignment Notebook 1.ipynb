# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Jennifer Gregory__
# Applications Analyst

# %% [markdown]
# _I am interested in data science because I love spreadsheets and data sets.  This seems like such an analytical field, and yet so very creative and visual.  Data can tell stories!_

# %% [markdown]
# ### Cell 5 is showing the sum of nine and five.

# %%
(9+5)

# %% [markdown]
# ***
# 1. Number One
# 2. Number Two
# 3. Number Three
# [link text] (http://coursera.org)
